# %% [markdown]
# # Parking Violations Issued - Fiscal Year 2022
# This dataset provides data on Parking Violations Issued between July 1, 2021 to June 30, 2022. In New York City, the fiscal year begins on July 1st of one calendar year and ends on June 30th of the following calendar year. Click here to find out more about the NYC Fiscal Year.
#
# download dataset from: https://data.cityofnewyork.us/City-Government/Parking-Violations-Issued-Fiscal-Year-2022/7mxj-7a6y/about_data

# %%
import pandas as pd 
import os

# %%
# Load 5 columns of data
df = pd.read_parquet(
    "C:\\Users\\hamza\\Documents\\Github\\nyc_parking_violations_2022.parquet",
    columns=["Registration State", "Violation Description", "Vehicle Body Type", "Issue Date", "Summons Number"]
)

# %%
df.sample(10)
# Out:
#          Registration State           Violation Description Vehicle Body Type
# 2342640                  NY  38-Failure to Dsplay Meter Rec              MOPD  \
# 4352680                  NY    21-No Parking (street clean)              4DSD
# 8612165                  MA  38-Failure to Dsplay Meter Rec              SUBN
# 8112825                  NY  38-Failure to Dsplay Meter Rec              4DSD
# 14626895                 NY  PHTO SCHOOL ZN SPEED VIOLATION              4DSD
# 14350358                 NY        20A-No Parking (Non-COM)              SUBN
# 5922864                  NY  PHTO SCHOOL ZN SPEED VIOLATION              4DSD
# 298472                   NY  PHTO SCHOOL ZN SPEED VIOLATION              SUBN
# 14933130                 NJ          19-No Stand (bus stop)              SUBN
# 6924937                  NY    21-No Parking (street clean)              SUBN
#
#           Issue Date  Summons Number
# 2342640   08/07/2021      8897121925
# 4352680   10/08/2021      8952488350
# 8612165   12/29/2021      8683647160
# 8112825   01/17/2022      8844632147
# 14626895  06/15/2022      4783027079
# 14350358  06/03/2022      8905330290
# 5922864   11/09/2021      4756047427
# 298472    07/23/2021      4741566997
# 14933130  06/17/2022      8702347283
# 6924937   12/03/2021      8884307119

# %%
# Load 5 columns of data
df2 = pd.read_parquet(
    "C:\\Users\\hamza\\Documents\\Github\\nyc_parking_violations_2022.parquet"
)
df2.sample(10)
# Out:
#           Summons Number Plate ID Registration State Plate Type  Issue Date
# 3063769       8825079503  JBV4532                 NC        PAS  09/11/2021  \
# 2698030       8968282286  15540MN                 NY        COM  08/10/2021
# 9078473       4768031717  HPE5616                 NY        PAS  02/15/2022
# 2218422       8810070148  539253N                 NJ        PAS  08/25/2021
# 9393396       2003272124  176701B                 ME        PAS  02/09/2022
# 11085475      8883677237  EFB6583                 NY        PAS  03/16/2022
# 5917308       4756034391  CRA8144                 NY        PAS  11/09/2021
# 844940        8966968806  16340PF                 NY        APP  07/06/2021
# 2115921       4746116003  KNU9861                 NY        PAS  08/20/2021
# 1738553       8977078430  KPC7654                 NY        PAS  08/05/2021
#
#           Violation Code Vehicle Body Type Vehicle Make Issuing Agency
# 3063769               40              4DSD        DODGE              T  \
# 2698030               46               VAN         FORD              T
# 9078473               36              SUBN          GMC              V
# 2218422               21              SUBN        HONDA              T
# 9393396               66              TRLR          N/S              S
# 11085475              74              4DSD        ME/BE              T
# 5917308               36              PICK        NISSA              V
# 844940                19              TRAC        FRUEH              T
# 2115921               36              SUBN        HYUND              V
# 1738553               21              SUBN        CHEVR              T
#
#           Street Code1  ...  Vehicle Color  Unregistered Vehicle?
# 3063769              0  ...          WHITE                    NaN  \
# 2698030          59520  ...             WH                    NaN
# 9078473              0  ...             BK                    NaN
# 2218422          16290  ...            RED                    NaN
# 9393396          46420  ...             WH                    NaN
# 11085475         25390  ...             WH                    NaN
# 5917308              0  ...             GY                    NaN
# 844940           78050  ...             RD                    NaN
# 2115921              0  ...             BL                    NaN
# 1738553          10030  ...             GR                    NaN
#
#           Vehicle Year  Meter Number  Feet From Curb  Violation Post Code
# 3063769              0          <NA>               0                   05  \
# 2698030           2020          <NA>               0                   42
# 9078473           2020          <NA>               0                 <NA>
# 2218422              0          <NA>               0                 51-A
# 9393396              0          <NA>               0                 <NA>
# 11085475          2020          <NA>               0                   10
# 5917308           2008          <NA>               0                 <NA>
# 844940            2005          <NA>               0                   09
# 2115921           2021          <NA>               0                 <NA>
# 1738553           2002          <NA>               0                    E
#
#                    Violation Description No Standing or Stopping Violation
# 3063769                  40-Fire Hydrant                               NaN  \
# 2698030   46B-Double Parking (Com-100Ft)                               NaN
# 9078473   PHTO SCHOOL ZN SPEED VIOLATION                               NaN
# 2218422     21-No Parking (street clean)                               NaN
# 9393396                 Detached Trailer                               NaN
# 11085475  74A-Improperly Displayed Plate                               NaN
# 5917308   PHTO SCHOOL ZN SPEED VIOLATION                               NaN
# 844940            19-No Stand (bus stop)                               NaN
# 2115921   PHTO SCHOOL ZN SPEED VIOLATION                               NaN
# 1738553     21-No Parking (street clean)                               NaN
#
#          Hydrant Violation Double Parking Violation
# 3063769                NaN                      NaN
# 2698030                NaN                      NaN
# 9078473                NaN                      NaN
# 2218422                NaN                      NaN
# 9393396                NaN                      NaN
# 11085475               NaN                      NaN
# 5917308                NaN                      NaN
# 844940                 NaN                      NaN
# 2115921                NaN                      NaN
# 1738553                NaN                      NaN
#
# [10 rows x 43 columns]

# %% [markdown]
# ### Save parquet file as CSV for analysis on MSSMS

# %%
df.to_csv("C:\\Users\\hamza\\Documents\\Github\\nyc_parking_violations_2022.csv", index=False)

# %% [markdown]
# ### Which parking violation is most commonly comitted by vehicles from various U.S states?
# i.e., Print the most commonly comittied parking violation in each state

# %%
# Group by state and violations
violations_count = df.groupby(['Registration State', 'Violation Description']).size()

# add violations count to dataframe
violations_df = violations_count.reset_index(name='Count')

# Sort by violation count for each state
violations_df_sorted = violations_df.sort_values(by=['Registration State', 'Count'], ascending=[True, False])

# Choose only the highest violation count for each state
violations_by_state = violations_df_sorted.groupby('Registration State').first().reset_index()
violations_by_state
# Out:
#    Registration State           Violation Description  Count
# 0                  99                            <NA>  17550
# 1                  AB                  14-No Standing     22
# 2                  AK  PHTO SCHOOL ZN SPEED VIOLATION    125
# 3                  AL  PHTO SCHOOL ZN SPEED VIOLATION   3668
# 4                  AR  PHTO SCHOOL ZN SPEED VIOLATION    537
# ..                ...                             ...    ...
# 62                 VT  PHTO SCHOOL ZN SPEED VIOLATION   3024
# 63                 WA    21-No Parking (street clean)   3732
# 64                 WI                  14-No Standing   1639
# 65                 WV  PHTO SCHOOL ZN SPEED VIOLATION   1185
# 66                 WY    21-No Parking (street clean)    138
#
# [67 rows x 3 columns]

# %% [markdown]
# ### Which vehicle body types are most frequently involved in parking violations?

# %%
# Group by vehicle body type
body_types = df.groupby(['Vehicle Body Type']).size().reset_index(name='Count')

# sort by count 
body_types_sorted = body_types.sort_values(['Count', ], ascending=False)
body_types_sorted
# Out:
#     Vehicle Body Type    Count
# 792              SUBN  6449007
# 50               4DSD  4402991
# 918               VAN  1317899
# 290              DELV   436430
# 663              PICK   429798
# ..                ...      ...
# 183              CARY        1
# 421              ISUZ        1
# 423              IXMR        1
# 139              BILB        1
# 597              ONEL        1
#
# [967 rows x 2 columns]

# %% [markdown]
# ### How do parking violations vary across days of the week?
# The result below reveals that there are much more parking tickets on weekdays compared to weekends which intuitively makes sense.

# %%
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

# Convert Issue Date to Datetime object 
df['Issue Date'] = df['Issue Date'].astype('datetime64[ms]')

# Map each Issue Date to the corresponding Day in the week
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

#
df.groupby(['issue_weekday'])["Summons Number"].count().sort_values()
# Out:
# issue_weekday
# Sunday        462992
# Saturday     1108385
# Monday       2488563
# Wednesday    2760088
# Tuesday      2809949
# Friday       2891679
# Thursday     2913951
# Name: Summons Number, dtype: int64

# %%
print('testing git from mac')
# Out:
# testing git from mac
